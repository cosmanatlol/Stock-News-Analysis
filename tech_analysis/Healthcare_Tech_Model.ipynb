# %%
import pandas as pd
import numpy as np
import yfinance as yf
import pandas_ta as ta
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb
import matplotlib.pyplot as plt

# Preprocessing and feature extraction
def preprocess(stock_symbols, start, end):
    strat = ta.Strategy(
        name='Best Strategy Ever',
        ta=[
            {'kind':'ema', 'length':10, 'col_names':'ema_10'},
            {'kind':'ema', 'length':25, 'col_names':'ema_25'},
            {'kind':'ema', 'length':50, 'col_names':'ema_50'},
            {'kind':'ema', 'length':100, 'col_names':'ema_100'},
            {'kind':'hma', 'length':10, 'col_names':'hma_10'},
            {'kind':'hma', 'length':25, 'col_names':'hma_25'},
            {'kind':'hma', 'length':50, 'col_names':'hma_50'},
            {'kind':'hma', 'length':100, 'col_names':'hma_100'},
            {'kind':'macd', 'col_names':('macd', 'macd_h', 'macd_s')},
            {'kind':'rsi', 'col_names':'rsi'},
            {'kind':'mom', 'col_names':'momentum'},
            {'kind':'bbands', 'std':1, 'col_names':('BBL', 'BBM', 'BBU', 'BBB', 'BBP')},
            {'kind':'ao', 'col_names':'ao'},
            {'kind':'adx', 'col_names':('adx', 'dmp', 'dmn')},
            {'kind':'chop', 'col_names':'chop'},
        ]
    )
    stock_data = []
    for symbol in stock_symbols:
        data = yf.download(symbol, start=start, end=end).reset_index()
        data.ta.strategy(strat)
        data['pct_change'] = data['Close'].pct_change()
        data['target'] = data['Close'].shift(-1)  # Predict next day's price
        data['Symbol'] = symbol  # Add a column for stock symbol
        stock_data.append(data.dropna())
    return pd.concat(stock_data, ignore_index=True)

# Predict for the next N days
def predict_next_days_for_stock(model, stock_data, stock_features, days=10):
    latest_data = stock_data.tail(days).copy()
    latest_features = stock_features.tail(days)
    predictions = model.predict(latest_features)
    return predictions

# Main workflow
if __name__ == "__main__":
    # Define inputs
    start_date = "2024-01-01"
    end_date = "2025-01-01"
    #XLV-61 
    healthcare_stocks_test = [
        "ISRG", "LLY", "IDXX", "BSX", "EW", "DHR", "SYK", "CI", "BMY", "CVS"
    ]

    # Preprocess data
    data = preprocess(healthcare_stocks_test, start_date, end_date)

    # Prepare features and target
    features = data.drop(columns=['Date', 'Close', 'target', 'Symbol'])
    target = data['target']

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

    # Train XGBoost model
    xg_reg = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, max_depth=6, learning_rate=0.1)
    xg_reg.fit(X_train, y_train)

    # Make predictions
    predictions = xg_reg.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, predictions)
    mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
    r2 = r2_score(y_test, predictions)

    print(f"Mean Squared Error: {mse}")
    print(f"MAPE: {mape}%")
    print(f"R² Score: {r2}")

    # Plot feature importance
    xgb.plot_importance(xg_reg)
    plt.show()

    # Predict next 10 days for all stocks
    all_predictions = {}
    for stock in healthcare_stocks_test:
        print(f"\nPredicting for {stock}...")
        
        # Filter data for the specific stock
        stock_data = data[data['Symbol'] == stock]
        stock_features = stock_data.drop(columns=['Date', 'Close', 'target', 'Symbol'])

        # Predict for the next 10 days
        predictions = predict_next_days_for_stock(xg_reg, stock_data, stock_features, days=10)
        all_predictions[stock] = predictions
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Mean Squared Error: 125.06239943602371
# MAPE: 1.6510934893790317%
# R² Score: 0.9979255354517784
# Predicting for ISRG...
#
# Predicting for LLY...
#
# Predicting for IDXX...
#
# Predicting for BSX...
#
# Predicting for EW...
#
# Predicting for DHR...
#
# Predicting for SYK...
#
# Predicting for CI...
#
# Predicting for BMY...
#
# Predicting for CVS...

# %%
# Predict next 10 days for all stocks and compare with actual prices
all_predictions = {}
all_actuals = {}
all_differences = {}
average_percentage_differences = {}

for stock in healthcare_stocks_test:
    print(f"\nPredicting for {stock}...\n")
    
    # Filter data for the specific stock
    stock_data = data[data['Symbol'] == stock]
    stock_features = stock_data.drop(columns=['Date', 'Close', 'target', 'Symbol'])  # Exclude 'Symbol' from features

    # Predict for the next 10 days
    predictions = predict_next_days_for_stock(xg_reg, stock_data, stock_features, days=10)
    all_predictions[stock] = predictions
    
    # Fetch actual future prices (next 10 days) for comparison
    future_data = yf.download(stock, start=end_date, end="2025-02-10")  # Assuming the next 10 days are after the end_date
    
    # Ensure that we have enough data
    if len(future_data) >= 10:
        actual_prices = future_data['Close'].head(10).values
        all_actuals[stock] = actual_prices
    else:
        print(f"Warning: Not enough data for {stock}. Skipping comparison.")
        all_actuals[stock] = np.array([])  # Set an empty array if there is not enough data

# Calculate the average percentage difference for each stock
for stock in healthcare_stocks_test:
    print(f"\n{stock} Predictions vs Actuals for the Next 10 Days:")
    predictions = all_predictions[stock]
    actuals = all_actuals[stock]
    
    # Check if actuals are empty
    if actuals.size > 0:
        differences = predictions - actuals
        percentage_differences = (differences / actuals) * 100

        for day in range(10):
            print(f"Day {day + 1}: Predicted Price = {predictions[day]:.2f}, Actual Price = {actuals[day]:.2f}, "
                  f"Difference = {differences[day]:.2f}, Percentage Difference = {percentage_differences[day]:.2f}%")
        
        # Calculate the average percentage difference
        avg_percentage_diff = np.mean(np.abs(percentage_differences))
        average_percentage_differences[stock] = avg_percentage_diff
        print(f"Average Percentage Difference for {stock}: {avg_percentage_diff:.2f}%")
    else:
        print("No actual data available for comparison.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Predicting for ISRG...
#
#
# Predicting for LLY...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Predicting for IDXX...
#
#
# Predicting for BSX...
#
#
# Predicting for EW...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Predicting for DHR...
#
#
# Predicting for SYK...
# [*********************100%***********************]  1 of 1 completed
# Predicting for CI...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Predicting for BMY...
#
#
# Predicting for CVS...
# [*********************100%***********************]  1 of 1 completed
# ISRG Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 543.36, Actual Price = 524.03, Difference = 19.33, Percentage Difference = 3.69%
# Day 2: Predicted Price = 527.95, Actual Price = 535.29, Difference = -7.34, Percentage Difference = -1.37%
# Day 3: Predicted Price = 524.86, Actual Price = 542.37, Difference = -17.51, Percentage Difference = -3.23%
# Day 4: Predicted Price = 525.57, Actual Price = 531.88, Difference = -6.31, Percentage Difference = -1.19%
# Day 5: Predicted Price = 528.14, Actual Price = 544.02, Difference = -15.88, Percentage Difference = -2.92%
# Day 6: Predicted Price = 535.16, Actual Price = 547.47, Difference = -12.31, Percentage Difference = -2.25%
# Day 7: Predicted Price = 537.87, Actual Price = 539.75, Difference = -1.88, Percentage Difference = -0.35%
# Day 8: Predicted Price = 535.41, Actual Price = 538.88, Difference = -3.47, Percentage Difference = -0.64%
# Day 9: Predicted Price = 532.47, Actual Price = 580.11, Difference = -47.64, Percentage Difference = -8.21%
# Day 10: Predicted Price = 523.44, Actual Price = 584.08, Difference = -60.64, Percentage Difference = -10.38%
# Average Percentage Difference for ISRG: 3.42%
#
# LLY Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 779.38, Actual Price = 778.07, Difference = 1.31, Percentage Difference = 0.17%
# Day 2: Predicted Price = 783.11, Actual Price = 781.98, Difference = 1.13, Percentage Difference = 0.14%
# Day 3: Predicted Price = 758.40, Actual Price = 765.10, Difference = -6.70, Percentage Difference = -0.88%
# Day 4: Predicted Price = 768.60, Actual Price = 773.29, Difference = -4.69, Percentage Difference = -0.61%
# Day 5: Predicted Price = 794.42, Actual Price = 787.22, Difference = 7.20, Percentage Difference = 0.92%
# Day 6: Predicted Price = 795.16, Actual Price = 799.90, Difference = -4.74, Percentage Difference = -0.59%
# Day 7: Predicted Price = 793.03, Actual Price = 797.48, Difference = -4.45, Percentage Difference = -0.56%
# Day 8: Predicted Price = 783.85, Actual Price = 744.91, Difference = 38.94, Percentage Difference = 5.23%
# Day 9: Predicted Price = 775.37, Actual Price = 746.74, Difference = 28.63, Percentage Difference = 3.83%
# Day 10: Predicted Price = 769.73, Actual Price = 757.60, Difference = 12.13, Percentage Difference = 1.60%
# Average Percentage Difference for LLY: 1.45%
#
# IDXX Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 427.12, Actual Price = 408.85, Difference = 18.27, Percentage Difference = 4.47%
# Day 2: Predicted Price = 413.05, Actual Price = 415.53, Difference = -2.48, Percentage Difference = -0.60%
# Day 3: Predicted Price = 411.26, Actual Price = 429.16, Difference = -17.90, Percentage Difference = -4.17%
# Day 4: Predicted Price = 411.68, Actual Price = 427.26, Difference = -15.58, Percentage Difference = -3.65%
# Day 5: Predicted Price = 410.94, Actual Price = 432.36, Difference = -21.42, Percentage Difference = -4.95%
# Day 6: Predicted Price = 413.71, Actual Price = 418.05, Difference = -4.34, Percentage Difference = -1.04%
# Day 7: Predicted Price = 415.19, Actual Price = 422.62, Difference = -7.43, Percentage Difference = -1.76%
# Day 8: Predicted Price = 416.00, Actual Price = 418.63, Difference = -2.63, Percentage Difference = -0.63%
# Day 9: Predicted Price = 414.11, Actual Price = 422.92, Difference = -8.81, Percentage Difference = -2.08%
# Day 10: Predicted Price = 409.92, Actual Price = 428.62, Difference = -18.70, Percentage Difference = -4.36%
# Average Percentage Difference for IDXX: 2.77%
#
# BSX Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 90.06, Actual Price = 89.38, Difference = 0.68, Percentage Difference = 0.76%
# Day 2: Predicted Price = 89.73, Actual Price = 90.69, Difference = -0.96, Percentage Difference = -1.05%
# Day 3: Predicted Price = 88.80, Actual Price = 91.29, Difference = -2.49, Percentage Difference = -2.72%
# Day 4: Predicted Price = 89.34, Actual Price = 91.99, Difference = -2.65, Percentage Difference = -2.88%
# Day 5: Predicted Price = 89.21, Actual Price = 95.95, Difference = -6.74, Percentage Difference = -7.02%
# Day 6: Predicted Price = 89.99, Actual Price = 94.88, Difference = -4.89, Percentage Difference = -5.15%
# Day 7: Predicted Price = 91.45, Actual Price = 94.61, Difference = -3.16, Percentage Difference = -3.34%
# Day 8: Predicted Price = 91.19, Actual Price = 95.65, Difference = -4.46, Percentage Difference = -4.66%
# Day 9: Predicted Price = 90.40, Actual Price = 96.89, Difference = -6.49, Percentage Difference = -6.70%
# Day 10: Predicted Price = 89.11, Actual Price = 98.17, Difference = -9.06, Percentage Difference = -9.23%
# Average Percentage Difference for BSX: 4.35%
#
# EW Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 74.35, Actual Price = 72.59, Difference = 1.76, Percentage Difference = 2.42%
# Day 2: Predicted Price = 74.24, Actual Price = 73.91, Difference = 0.33, Percentage Difference = 0.44%
# Day 3: Predicted Price = 74.19, Actual Price = 73.54, Difference = 0.65, Percentage Difference = 0.88%
# Day 4: Predicted Price = 74.36, Actual Price = 73.64, Difference = 0.72, Percentage Difference = 0.97%
# Day 5: Predicted Price = 74.35, Actual Price = 74.15, Difference = 0.20, Percentage Difference = 0.27%
# Day 6: Predicted Price = 74.51, Actual Price = 73.42, Difference = 1.09, Percentage Difference = 1.49%
# Day 7: Predicted Price = 74.51, Actual Price = 71.09, Difference = 3.42, Percentage Difference = 4.81%
# Day 8: Predicted Price = 76.39, Actual Price = 71.04, Difference = 5.35, Percentage Difference = 7.54%
# Day 9: Predicted Price = 76.30, Actual Price = 70.28, Difference = 6.02, Percentage Difference = 8.57%
# Day 10: Predicted Price = 74.32, Actual Price = 69.86, Difference = 4.46, Percentage Difference = 6.38%
# Average Percentage Difference for EW: 3.38%
#
# DHR Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 232.57, Actual Price = 229.81, Difference = 2.76, Percentage Difference = 1.20%
# Day 2: Predicted Price = 228.90, Actual Price = 234.84, Difference = -5.94, Percentage Difference = -2.53%
# Day 3: Predicted Price = 226.18, Actual Price = 238.20, Difference = -12.02, Percentage Difference = -5.05%
# Day 4: Predicted Price = 228.47, Actual Price = 239.10, Difference = -10.63, Percentage Difference = -4.45%
# Day 5: Predicted Price = 97.53, Actual Price = 238.09, Difference = -140.56, Percentage Difference = -59.04%
# Day 6: Predicted Price = 230.14, Actual Price = 235.07, Difference = -4.93, Percentage Difference = -2.10%
# Day 7: Predicted Price = 231.43, Actual Price = 239.88, Difference = -8.45, Percentage Difference = -3.52%
# Day 8: Predicted Price = 231.02, Actual Price = 237.62, Difference = -6.60, Percentage Difference = -2.78%
# Day 9: Predicted Price = 230.34, Actual Price = 237.97, Difference = -7.63, Percentage Difference = -3.21%
# Day 10: Predicted Price = 229.61, Actual Price = 241.90, Difference = -12.29, Percentage Difference = -5.08%
# Average Percentage Difference for DHR: 8.89%
#
# SYK Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 372.11, Actual Price = 358.72, Difference = 13.39, Percentage Difference = 3.73%
# Day 2: Predicted Price = 361.57, Actual Price = 361.52, Difference = 0.05, Percentage Difference = 0.01%
# Day 3: Predicted Price = 362.29, Actual Price = 361.36, Difference = 0.93, Percentage Difference = 0.26%
# Day 4: Predicted Price = 363.06, Actual Price = 355.18, Difference = 7.88, Percentage Difference = 2.22%
# Day 5: Predicted Price = 366.45, Actual Price = 364.10, Difference = 2.35, Percentage Difference = 0.65%
# Day 6: Predicted Price = 367.29, Actual Price = 365.66, Difference = 1.63, Percentage Difference = 0.45%
# Day 7: Predicted Price = 367.04, Actual Price = 360.98, Difference = 6.06, Percentage Difference = 1.68%
# Day 8: Predicted Price = 368.81, Actual Price = 362.80, Difference = 6.01, Percentage Difference = 1.66%
# Day 9: Predicted Price = 363.12, Actual Price = 368.61, Difference = -5.49, Percentage Difference = -1.49%
# Day 10: Predicted Price = 360.23, Actual Price = 381.79, Difference = -21.56, Percentage Difference = -5.65%
# Average Percentage Difference for SYK: 1.78%
#
# CI Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 279.00, Actual Price = 274.49, Difference = 4.51, Percentage Difference = 1.64%
# Day 2: Predicted Price = 281.17, Actual Price = 280.70, Difference = 0.47, Percentage Difference = 0.17%
# Day 3: Predicted Price = 276.35, Actual Price = 279.66, Difference = -3.31, Percentage Difference = -1.18%
# Day 4: Predicted Price = 277.20, Actual Price = 279.93, Difference = -2.73, Percentage Difference = -0.98%
# Day 5: Predicted Price = 280.15, Actual Price = 279.32, Difference = 0.83, Percentage Difference = 0.30%
# Day 6: Predicted Price = 277.96, Actual Price = 278.99, Difference = -1.03, Percentage Difference = -0.37%
# Day 7: Predicted Price = 280.86, Actual Price = 282.45, Difference = -1.59, Percentage Difference = -0.56%
# Day 8: Predicted Price = 278.80, Actual Price = 285.03, Difference = -6.23, Percentage Difference = -2.19%
# Day 9: Predicted Price = 276.00, Actual Price = 284.58, Difference = -8.58, Percentage Difference = -3.01%
# Day 10: Predicted Price = 275.50, Actual Price = 280.97, Difference = -5.47, Percentage Difference = -1.95%
# Average Percentage Difference for CI: 1.24%
#
# BMY Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 56.31, Actual Price = 56.79, Difference = -0.48, Percentage Difference = -0.84%
# Day 2: Predicted Price = 57.56, Actual Price = 56.57, Difference = 0.99, Percentage Difference = 1.75%
# Day 3: Predicted Price = 57.26, Actual Price = 56.68, Difference = 0.58, Percentage Difference = 1.03%
# Day 4: Predicted Price = 56.27, Actual Price = 57.14, Difference = -0.87, Percentage Difference = -1.52%
# Day 5: Predicted Price = 57.49, Actual Price = 56.81, Difference = 0.68, Percentage Difference = 1.20%
# Day 6: Predicted Price = 57.88, Actual Price = 55.83, Difference = 2.05, Percentage Difference = 3.68%
# Day 7: Predicted Price = 57.91, Actual Price = 55.36, Difference = 2.55, Percentage Difference = 4.61%
# Day 8: Predicted Price = 58.21, Actual Price = 55.74, Difference = 2.47, Percentage Difference = 4.43%
# Day 9: Predicted Price = 57.60, Actual Price = 55.91, Difference = 1.69, Percentage Difference = 3.02%
# Day 10: Predicted Price = 56.50, Actual Price = 56.38, Difference = 0.12, Percentage Difference = 0.21%
# Average Percentage Difference for BMY: 2.23%
#
# CVS Predictions vs Actuals for the Next 10 Days:
# Day 1: Predicted Price = 46.73, Actual Price = 44.22, Difference = 2.51, Percentage Difference = 5.69%
# Day 2: Predicted Price = 45.42, Actual Price = 45.77, Difference = -0.35, Percentage Difference = -0.76%
# Day 3: Predicted Price = 45.35, Actual Price = 45.82, Difference = -0.47, Percentage Difference = -1.03%
# Day 4: Predicted Price = 43.96, Actual Price = 45.78, Difference = -1.82, Percentage Difference = -3.97%
# Day 5: Predicted Price = 43.77, Actual Price = 46.01, Difference = -2.24, Percentage Difference = -4.86%
# Day 6: Predicted Price = 43.77, Actual Price = 48.01, Difference = -4.24, Percentage Difference = -8.84%
# Day 7: Predicted Price = 44.68, Actual Price = 51.52, Difference = -6.84, Percentage Difference = -13.28%
# Day 8: Predicted Price = 45.19, Actual Price = 51.57, Difference = -6.38, Percentage Difference = -12.37%
# Day 9: Predicted Price = 44.33, Actual Price = 52.14, Difference = -7.81, Percentage Difference = -14.98%
# Day 10: Predicted Price = 44.99, Actual Price = 51.96, Difference = -6.97, Percentage Difference = -13.42%
# Average Percentage Difference for CVS: 7.92%

# %%
# Print the average percentage difference for all stocks
print("\nAverage Percentage Difference for Each Stock:")
for stock, avg_diff in average_percentage_differences.items():
    print(f"{stock}: {avg_diff:.2f}%")
# Out:
# Average Percentage Difference for Each Stock:
# ISRG: 3.42%
# LLY: 1.45%
# IDXX: 2.77%
# BSX: 4.35%
# EW: 3.38%
# DHR: 8.89%
# SYK: 1.78%
# CI: 1.24%
# BMY: 2.23%
# CVS: 7.92%
