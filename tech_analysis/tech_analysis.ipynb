# %%
import yfinance as yf
import pandas as pd
import numpy as np
from preprocessing import *

# %%
healthcare_ticker = ['ISRG', 'LLY', 'IDXX', 'BSX', 'EW', 'DHR', 'SYK', 'CI', 'BMY', 'CVS']
energy_ticker = ['WMB', 'KMI', 'OKE', 'OXY', 'CVX', 'XOM', 'PSX', 'EOG', 'FANG', 'SLB']
technology_ticker = ['PLTR', 'CRWD', 'NOW', 'FICO', 'PANW', 'ANET', 'CDNS', 'QCOM', 'DELL', 'MU']

# %%
start = '2019-01-01'
end = '2025-01-10'
healthcare_dic = preprocess(healthcare_ticker, start, end)
energy_dic = preprocess(energy_ticker, start, end)
tech_dic = preprocess(technology_ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
healthcare_dic['ISRG']
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 108  2019-06-07  162.153336  166.626663  161.786667  166.346664  166.346664
# 109  2019-06-10  166.866669  172.023331  166.866669  169.906662  169.906662
# 110  2019-06-11  170.906662  172.173340  167.526672  168.853333  168.853333
# 111  2019-06-12  168.593338  169.949997  166.576660  167.306671  167.306671
# 112  2019-06-13  167.963333  169.253326  166.966660  168.533340  168.533340
# ...         ...         ...         ...         ...         ...         ...
# 1510 2025-01-02  521.190002  528.890015  520.919983  524.030029  524.030029
# 1511 2025-01-03  527.609985  536.650024  525.349976  535.289978  535.289978
# 1512 2025-01-06  535.289978  543.739990  532.150024  542.369995  542.369995
# 1513 2025-01-07  547.669983  550.000000  530.450012  531.880005  531.880005
# 1514 2025-01-08  533.330017  547.469971  532.000000  544.020020  544.020020
#
# ...
