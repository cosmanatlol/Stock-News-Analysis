# %%
import yfinance as yf
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

# Load sentiment data
sentiment_data = pd.read_csv("predictions2.csv")
unique_stocks = sentiment_data["stock"].unique()

# Initialize LabelEncoder
encoder = LabelEncoder()
encoder.fit(unique_stocks)

# Function to fetch stock data and compute technical indicators
def get_stock_data(ticker):
    stock = yf.download(ticker, start="2024-01-01", end="2025-02-22", interval="1d")
    stock.columns = stock.columns.droplevel(1) if isinstance(stock.columns, pd.MultiIndex) else stock.columns
    stock["Stock"] = ticker  # Add stock identifier
    
    # Calculate EMA
    stock["EMA_10"] = stock["Close"].ewm(span=10, adjust=False).mean()
    stock["EMA_25"] = stock["Close"].ewm(span=25, adjust=False).mean()

    # MACD Calculation
    short_ema = stock["Close"].ewm(span=12, adjust=False).mean()
    long_ema = stock["Close"].ewm(span=26, adjust=False).mean()
    stock["MACD_12_26_9"] = short_ema - long_ema
    stock["MACDs_12_26_9"] = stock["MACD_12_26_9"].ewm(span=9, adjust=False).mean()
    stock["MACDh_12_26_9"] = stock["MACD_12_26_9"] - stock["MACDs_12_26_9"]

    # Bollinger Bands
    stock["BBM_5"] = stock["Close"].rolling(window=5).mean()
    stock["BBU_5"] = stock["BBM_5"] + (stock["Close"].rolling(window=5).std() * 1)
    stock["BBL_5"] = stock["BBM_5"] - (stock["Close"].rolling(window=5).std() * 1)
    stock["BBB_5"] = (stock["BBU_5"] - stock["BBL_5"]) / stock["BBM_5"]
    stock["BBP_5"] = (stock["Close"] - stock["BBL_5"]) / (stock["BBU_5"] - stock["BBL_5"])
    stock["target_1"] = stock["Close"].shift(-1)
    
    # Encode stock name
    stock["Stock"] = encoder.transform([ticker])[0]
    
    return stock.iloc[:-1]  # Remove last row

# Fetch and combine data for all stocks
all_data = pd.concat([get_stock_data(stock) for stock in unique_stocks])
all_data = all_data.reset_index()
all_data['Date'] = pd.to_datetime(all_data['Date'])
all_data = all_data[all_data['Date'] >= '2025-01-22']
sen_data = all_data.copy()
all_data = all_data.drop(columns=["Date"])
all_data = all_data.dropna()
sentiment_data = sentiment_data.rename(columns={'stock': 'Stock', 'date': 'Date'})
sentiment_data["Stock"] = encoder.transform(sentiment_data["Stock"])
sen_data['Date'] = pd.to_datetime(sen_data['Date'])
sentiment_data['Date'] = pd.to_datetime(sentiment_data['Date'])
merged_data = sen_data.merge(sentiment_data, on=['Date', 'Stock'], how='left')
merged_data = merged_data.drop(columns=["Date"])
merged_data = merged_data.dropna()

# Split features and target
features = all_data.drop(columns=["target_1"])
target = all_data["target_1"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=1)

# Train the model
model = XGBRegressor(objective="reg:squarederror", n_estimators=100)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Calculate MSE, MAPE, and R² for test set
mse = mean_squared_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print results
print(f"\nModel Performance on Test Set:")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape * 100:.2f}%")
print(f"R-squared (R²): {r2:.4f}")

def predict_next_days(model, last_row, feature_columns, days=5):
    predictions = []
    last_row = last_row.copy()
    
    for _ in range(days):
        feature_data = pd.DataFrame([last_row[feature_columns]])

        # Predict the next price
        predicted_price = model.predict(feature_data)[0]
        predictions.append(predicted_price)

        # Update the last row with new predicted price
        last_row["Close"] = predicted_price

        # Recalculate EMA
        last_row["EMA_10"] = (last_row["EMA_10"] * 9 + predicted_price) / 10
        last_row["EMA_25"] = (last_row["EMA_25"] * 24 + predicted_price) / 25

        # Recalculate MACD components
        short_ema = (last_row["MACD_12_26_9"] * 11 + predicted_price) / 12
        long_ema = (last_row["MACD_12_26_9"] * 25 + predicted_price) / 26
        last_row["MACD_12_26_9"] = short_ema - long_ema
        last_row["MACDs_12_26_9"] = (last_row["MACDs_12_26_9"] * 8 + last_row["MACD_12_26_9"]) / 9
        last_row["MACDh_12_26_9"] = last_row["MACD_12_26_9"] - last_row["MACDs_12_26_9"]

        # Recalculate Bollinger Bands
        last_row["BBM_5"] = (last_row["BBM_5"] * 4 + predicted_price) / 5
        last_row["BBU_5"] = last_row["BBM_5"] + (last_row["BBB_5"] * last_row["BBM_5"])
        last_row["BBL_5"] = last_row["BBM_5"] - (last_row["BBB_5"] * last_row["BBM_5"])
        last_row["BBP_5"] = (predicted_price - last_row["BBL_5"]) / (last_row["BBU_5"] - last_row["BBL_5"])

    return predictions

feature_columns = X_train.columns
future_predictions = {}

for stock in unique_stocks:
    stock_encoded = encoder.transform([stock])[0]
    last_row = all_data[all_data["Stock"] == stock_encoded].iloc[-1]
    future_predictions[stock] = predict_next_days(model, last_row, feature_columns, days=5)

# Display predictions
for stock, predictions in future_predictions.items():
    print(f"\nPredicted prices for {stock}:")
    for i, price in enumerate(predictions, start=1):
        print(f"Day {i}: {price:.2f}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Model Performance on Test Set:
# Mean Squared Error (MSE): 70.4969
# Mean Absolute Percentage Error (MAPE): 2.27%
# R-squared (R²): 0.9978
#
# Predicted prices for ISRG:
# Day 1: 591.90
# Day 2: 586.67
# Day 3: 586.75
# Day 4: 587.15
# Day 5: 587.26
#
# Predicted prices for IDXX:
# Day 1: 452.91
# Day 2: 455.90
# Day 3: 459.24
# Day 4: 459.47
# Day 5: 457.15
#
# Predicted prices for BSX:
# Day 1: 104.65
# Day 2: 101.56
# Day 3: 102.70
# Day 4: 102.40
# Day 5: 103.00
#
# Predicted prices for LLY:
# Day 1: 873.65
# Day 2: 912.32
# Day 3: 924.49
# Day 4: 924.49
# Day 5: 914.11
#
# Predicted prices for EW:
# Day 1: 73.21
# Day 2: 75.37
# Day 3: 73.41
# Day 4: 72.96
# Day 5: 72.80
#
# Predicted prices for ZTS:
# Day 1: 160.52
# Day 2: 162.11
# Day 3: 161.98
# Day 4: 162.06
# Day 5: 161.85
#
# Predicted prices for SYK:
# Day 1: 382.77
# Day 2: 389.18
# Day 3: 391.49
# Day 4: 400.24
# Day 5: 400.60
#
# Predicted prices for DHR:
# Day 1: 210.27
# Day 2: 215.46
# Day 3: 219.34
# Day 4: 224.88
# Day 5: 226.64
#
# Predicted prices for ABT:
# Day 1: 134.51
# Day 2: 132.59
# Day 3: 130.14
# Day 4: 128.02
# Day 5: 127.57
#
# Predicted prices for A:
# Day 1: 135.41
# Day 2: 133.27
# Day 3: 130.90
# Day 4: 132.97
# Day 5: 130.98
#
# Predicted prices for CVS:
# Day 1: 63.68
# Day 2: 63.07
# Day 3: 63.67
# Day 4: 63.55
# Day 5: 63.83
#
# Predicted prices for BMY:
# Day 1: 55.77
# Day 2: 55.53
# Day 3: 55.38
# Day 4: 56.41
# Day 5: 55.68
#
# Predicted prices for CI:
# Day 1: 299.69
# Day 2: 291.54
# Day 3: 291.94
# Day 4: 289.72
# Day 5: 286.41
#
# Predicted prices for MRK:
# Day 1: 89.36
# Day 2: 93.23
# Day 3: 94.86
# Day 4: 94.85
# Day 5: 94.28
#
# Predicted prices for PFE:
# Day 1: 26.16
# Day 2: 27.41
# Day 3: 28.80
# Day 4: 30.73
# Day 5: 34.69
#
# Predicted prices for WMB:
# Day 1: 57.61
# Day 2: 57.51
# Day 3: 57.54
# Day 4: 57.61
# Day 5: 57.28
#
# Predicted prices for KMI:
# Day 1: 26.37
# Day 2: 29.20
# Day 3: 27.87
# Day 4: 27.77
# Day 5: 28.06
#
# Predicted prices for OKE:
# Day 1: 98.16
# Day 2: 105.97
# Day 3: 108.61
# Day 4: 111.01
# Day 5: 110.52
#
# Predicted prices for BKR:
# Day 1: 45.81
# Day 2: 43.60
# Day 3: 44.42
# Day 4: 44.61
# Day 5: 45.15
#
# Predicted prices for CVX:
# Day 1: 156.97
# Day 2: 159.88
# Day 3: 164.26
# Day 4: 164.97
# Day 5: 163.35
#
# Predicted prices for XOM:
# Day 1: 110.47
# Day 2: 105.05
# Day 3: 102.28
# Day 4: 104.54
# Day 5: 102.79
#
# Predicted prices for MPC:
# Day 1: 154.44
# Day 2: 161.62
# Day 3: 163.08
# Day 4: 164.28
# Day 5: 164.35
#
# Predicted prices for EOG:
# Day 1: 133.34
# Day 2: 126.30
# Day 3: 122.47
# Day 4: 122.44
# Day 5: 122.34
#
# Predicted prices for SLB:
# Day 1: 41.68
# Day 2: 45.74
# Day 3: 41.69
# Day 4: 44.76
# Day 5: 44.04
#
# Predicted prices for COP:
# Day 1: 98.23
# Day 2: 104.69
# Day 3: 105.73
# Day 4: 108.00
# Day 5: 106.49
#
# Predicted prices for PSX:
# Day 1: 128.73
# Day 2: 123.89
# Day 3: 123.67
# Day 4: 123.57
# Day 5: 123.74
#
# Predicted prices for PLTR:
# Day 1: 101.35
# Day 2: 100.40
# Day 3: 100.47
# Day 4: 98.09
# Day 5: 96.86
#
# Predicted prices for CRWD:
# Day 1: 406.61
# Day 2: 391.65
# Day 3: 391.32
# Day 4: 389.14
# Day 5: 383.64
#
# Predicted prices for PANW:
# Day 1: 191.44
# Day 2: 190.54
# Day 3: 190.27
# Day 4: 191.23
# Day 5: 191.81
#
# Predicted prices for NOW:
# Day 1: 938.35
# Day 2: 963.84
# Day 3: 962.76
# Day 4: 962.28
# Day 5: 968.29
#
# Predicted prices for ANET:
# Day 1: 98.71
# Day 2: 99.71
# Day 3: 106.58
# Day 4: 105.90
# Day 5: 104.07
#
# Predicted prices for CDNS:
# Day 1: 258.41
# Day 2: 247.51
# Day 3: 246.50
# Day 4: 246.35
# Day 5: 235.98
#
# Predicted prices for FTNT:
# Day 1: 110.22
# Day 2: 102.36
# Day 3: 103.31
# Day 4: 104.35
# Day 5: 99.14
#
# Predicted prices for ADSK:
# Day 1: 285.03
# Day 2: 285.33
# Day 3: 284.92
# Day 4: 280.73
# Day 5: 281.10
#
# Predicted prices for MSI:
# Day 1: 421.84
# Day 2: 438.68
# Day 3: 437.51
# Day 4: 437.69
# Day 5: 435.50
#
# Predicted prices for AVGO:
# Day 1: 218.76
# Day 2: 217.80
# Day 3: 218.06
# Day 4: 218.44
# Day 5: 218.93
#
# Predicted prices for CSCO:
# Day 1: 63.96
# Day 2: 64.85
# Day 3: 65.58
# Day 4: 64.35
# Day 5: 65.24
#
# Predicted prices for NXPI:
# Day 1: 236.68
# Day 2: 210.57
# Day 3: 201.67
# Day 4: 217.48
# Day 5: 213.87
#
# Predicted prices for QCOM:
# Day 1: 166.61
# Day 2: 168.69
# Day 3: 168.54
# Day 4: 168.59
# Day 5: 168.30
#
# Predicted prices for DELL:
# Day 1: 117.64
# Day 2: 116.43
# Day 3: 114.74
# Day 4: 113.69
# Day 5: 106.09
#
# Predicted prices for MU:
# Day 1: 101.07
# Day 2: 106.41
# Day 3: 111.56
# Day 4: 112.59
# Day 5: 111.05
#
# Predicted prices for COST:
# Day 1: 1035.27
# Day 2: 1053.77
# Day 3: 1054.33
# Day 4: 1054.41
# Day 5: 1055.36
#
# Predicted prices for WMT:
# Day 1: 94.73
# Day 2: 96.18
# Day 3: 95.40
# Day 4: 95.54
# Day 5: 95.77
#
# Predicted prices for MNST:
# Day 1: 49.89
# Day 2: 49.91
# Day 3: 50.78
# Day 4: 50.26
# Day 5: 50.74
#
# Predicted prices for HSY:
# Day 1: 172.90
# Day 2: 171.41
# Day 3: 173.22
# Day 4: 172.89
# Day 5: 171.03
#
# Predicted prices for PG:
# Day 1: 170.10
# Day 2: 168.46
# Day 3: 168.85
# Day 4: 168.73
# Day 5: 168.84
#
# Predicted prices for CL:
# Day 1: 89.09
# Day 2: 94.10
# Day 3: 95.93
# Day 4: 96.17
# Day 5: 96.29
#
# Predicted prices for KO:
# Day 1: 71.34
# Day 2: 70.61
# Day 3: 71.70
# Day 4: 69.74
# Day 5: 70.59
#
# Predicted prices for PM:
# Day 1: 154.14
# Day 2: 151.80
# Day 3: 150.39
# Day 4: 149.65
# Day 5: 148.65
#
# Predicted prices for MDLZ:
# Day 1: 64.38
# Day 2: 67.45
# Day 3: 64.67
# Day 4: 63.83
# Day 5: 64.14
#
# Predicted prices for KVUE:
# Day 1: 23.34
# Day 2: 24.87
# Day 3: 23.41
# Day 4: 23.81
# Day 5: 23.90
#
# Predicted prices for TGT:
# Day 1: 124.76
# Day 2: 124.55
# Day 3: 124.97
# Day 4: 124.38
# Day 5: 123.77
#
# Predicted prices for KR:
# Day 1: 65.05
# Day 2: 65.11
# Day 3: 65.39
# Day 4: 65.73
# Day 5: 64.85
#
# Predicted prices for GIS:
# Day 1: 60.72
# Day 2: 63.14
# Day 3: 69.66
# Day 4: 69.24
# Day 5: 69.87
#
# Predicted prices for MO:
# Day 1: 54.89
# Day 2: 56.56
# Day 3: 55.10
# Day 4: 55.74
# Day 5: 56.50
#
# Predicted prices for KHC:
# Day 1: 31.10
# Day 2: 36.17
# Day 3: 36.18
# Day 4: 34.85
# Day 5: 36.35

# %%
# Feature selection
features = merged_data.drop(columns=["target_1"])
target = merged_data["target_1"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=1)
model = XGBRegressor(objective="reg:squarederror", n_estimators=100)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# Calculate MSE, MAPE, and R² for test set
mse = mean_squared_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print results
print(f"\nModel Performance on Test Set:")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape * 100:.2f}%")
print(f"R-squared (R²): {r2:.4f}")

# Predict next 5 days
def predict_next_days(model, last_row, feature_columns, days=5):
    predictions = []
    last_row = last_row.copy()
    
    for _ in range(days):
        feature_data = pd.DataFrame([last_row[feature_columns]])

        # Predict the next price
        predicted_price = model.predict(feature_data)[0]
        predictions.append(predicted_price)

        # Update the last row with new predicted price
        last_row["Close"] = predicted_price

        # Recalculate EMA
        last_row["EMA_10"] = (last_row["EMA_10"] * 9 + predicted_price) / 10
        last_row["EMA_25"] = (last_row["EMA_25"] * 24 + predicted_price) / 25

        # Recalculate MACD components
        short_ema = (last_row["MACD_12_26_9"] * 11 + predicted_price) / 12
        long_ema = (last_row["MACD_12_26_9"] * 25 + predicted_price) / 26
        last_row["MACD_12_26_9"] = short_ema - long_ema
        last_row["MACDs_12_26_9"] = (last_row["MACDs_12_26_9"] * 8 + last_row["MACD_12_26_9"]) / 9
        last_row["MACDh_12_26_9"] = last_row["MACD_12_26_9"] - last_row["MACDs_12_26_9"]

        # Recalculate Bollinger Bands
        last_row["BBM_5"] = (last_row["BBM_5"] * 4 + predicted_price) / 5
        last_row["BBU_5"] = last_row["BBM_5"] + (last_row["BBB_5"] * last_row["BBM_5"])
        last_row["BBL_5"] = last_row["BBM_5"] - (last_row["BBB_5"] * last_row["BBM_5"])
        last_row["BBP_5"] = (predicted_price - last_row["BBL_5"]) / (last_row["BBU_5"] - last_row["BBL_5"])

    return predictions

feature_columns = X_train.columns
future_predictions = {}

for stock in unique_stocks:
    stock_encoded = encoder.transform([stock])[0]
    last_row = merged_data[merged_data["Stock"] == stock_encoded].iloc[-1]
    future_predictions[stock] = predict_next_days(model, last_row, feature_columns, days=5)

# Display predictions
for stock, predictions in future_predictions.items():
    print(f"\nPredicted prices for {stock}:")
    for i, price in enumerate(predictions, start=1):
        print(f"Day {i}: {price:.2f}")
# Out:
# Model Performance on Test Set:
# Mean Squared Error (MSE): 86.1385
# Mean Absolute Percentage Error (MAPE): 1.70%
# R-squared (R²): 0.9978
#
# Predicted prices for ISRG:
# Day 1: 592.38
# Day 2: 644.14
# Day 3: 698.65
# Day 4: 698.65
# Day 5: 698.65
#
# Predicted prices for IDXX:
# Day 1: 452.80
# Day 2: 453.95
# Day 3: 453.81
# Day 4: 453.99
# Day 5: 453.75
#
# Predicted prices for BSX:
# Day 1: 104.50
# Day 2: 104.42
# Day 3: 102.58
# Day 4: 102.68
# Day 5: 102.68
#
# Predicted prices for LLY:
# Day 1: 873.74
# Day 2: 871.50
# Day 3: 871.44
# Day 4: 871.68
# Day 5: 871.04
#
# Predicted prices for EW:
# Day 1: 73.38
# Day 2: 71.22
# Day 3: 72.47
# Day 4: 70.92
# Day 5: 71.93
#
# Predicted prices for ZTS:
# Day 1: 160.00
# Day 2: 162.37
# Day 3: 161.29
# Day 4: 160.70
# Day 5: 159.31
#
# Predicted prices for SYK:
# Day 1: 382.69
# Day 2: 384.95
# Day 3: 388.11
# Day 4: 390.29
# Day 5: 391.19
#
# Predicted prices for DHR:
# Day 1: 208.76
# Day 2: 211.43
# Day 3: 210.47
# Day 4: 211.22
# Day 5: 211.54
#
# Predicted prices for ABT:
# Day 1: 134.59
# Day 2: 136.48
# Day 3: 136.72
# Day 4: 136.43
# Day 5: 136.23
#
# Predicted prices for A:
# Day 1: 135.41
# Day 2: 139.31
# Day 3: 142.68
# Day 4: 143.35
# Day 5: 142.29
#
# Predicted prices for CVS:
# Day 1: 63.49
# Day 2: 64.31
# Day 3: 63.35
# Day 4: 63.99
# Day 5: 64.07
#
# Predicted prices for BMY:
# Day 1: 55.77
# Day 2: 55.67
# Day 3: 55.67
# Day 4: 55.82
# Day 5: 55.72
#
# Predicted prices for CI:
# Day 1: 299.91
# Day 2: 294.66
# Day 3: 294.17
# Day 4: 294.36
# Day 5: 292.64
#
# Predicted prices for MRK:
# Day 1: 89.42
# Day 2: 88.40
# Day 3: 88.05
# Day 4: 87.12
# Day 5: 84.98
#
# Predicted prices for PFE:
# Day 1: 26.31
# Day 2: 27.31
# Day 3: 27.77
# Day 4: 27.81
# Day 5: 27.76
#
# Predicted prices for WMB:
# Day 1: 57.66
# Day 2: 56.28
# Day 3: 55.02
# Day 4: 55.07
# Day 5: 54.91
#
# Predicted prices for KMI:
# Day 1: 26.61
# Day 2: 26.15
# Day 3: 25.27
# Day 4: 24.72
# Day 5: 24.85
#
# Predicted prices for OKE:
# Day 1: 98.10
# Day 2: 98.87
# Day 3: 99.69
# Day 4: 98.51
# Day 5: 98.49
#
# Predicted prices for BKR:
# Day 1: 45.94
# Day 2: 43.88
# Day 3: 44.59
# Day 4: 44.72
# Day 5: 43.78
#
# Predicted prices for CVX:
# Day 1: 158.62
# Day 2: 159.46
# Day 3: 162.29
# Day 4: 162.57
# Day 5: 163.38
#
# Predicted prices for XOM:
# Day 1: 110.56
# Day 2: 111.52
# Day 3: 111.97
# Day 4: 110.65
# Day 5: 110.90
#
# Predicted prices for MPC:
# Day 1: 153.89
# Day 2: 153.06
# Day 3: 153.28
# Day 4: 152.42
# Day 5: 151.77
#
# Predicted prices for EOG:
# Day 1: 133.35
# Day 2: 130.90
# Day 3: 131.46
# Day 4: 130.16
# Day 5: 129.33
#
# Predicted prices for SLB:
# Day 1: 41.86
# Day 2: 40.86
# Day 3: 39.88
# Day 4: 29.77
# Day 5: 29.78
#
# Predicted prices for COP:
# Day 1: 98.48
# Day 2: 99.69
# Day 3: 100.30
# Day 4: 101.32
# Day 5: 101.20
#
# Predicted prices for PSX:
# Day 1: 129.26
# Day 2: 127.71
# Day 3: 126.92
# Day 4: 126.94
# Day 5: 126.92
#
# Predicted prices for PLTR:
# Day 1: 101.41
# Day 2: 103.16
# Day 3: 102.23
# Day 4: 98.56
# Day 5: 98.66
#
# Predicted prices for CRWD:
# Day 1: 433.25
# Day 2: 431.90
# Day 3: 430.62
# Day 4: 430.45
# Day 5: 429.00
#
# Predicted prices for PANW:
# Day 1: 191.32
# Day 2: 190.39
# Day 3: 190.30
# Day 4: 189.84
# Day 5: 190.10
#
# Predicted prices for NOW:
# Day 1: 938.56
# Day 2: 947.31
# Day 3: 964.34
# Day 4: 964.74
# Day 5: 973.72
#
# Predicted prices for ANET:
# Day 1: 98.64
# Day 2: 102.02
# Day 3: 102.05
# Day 4: 101.95
# Day 5: 101.66
#
# Predicted prices for CDNS:
# Day 1: 258.54
# Day 2: 270.44
# Day 3: 269.80
# Day 4: 263.65
# Day 5: 263.83
#
# Predicted prices for FTNT:
# Day 1: 110.09
# Day 2: 105.45
# Day 3: 105.54
# Day 4: 105.65
# Day 5: 105.95
#
# Predicted prices for ADSK:
# Day 1: 285.22
# Day 2: 272.17
# Day 3: 274.23
# Day 4: 271.97
# Day 5: 271.72
#
# Predicted prices for MSI:
# Day 1: 421.91
# Day 2: 427.99
# Day 3: 429.45
# Day 4: 428.88
# Day 5: 429.15
#
# Predicted prices for AVGO:
# Day 1: 218.55
# Day 2: 220.63
# Day 3: 219.88
# Day 4: 220.39
# Day 5: 219.87
#
# Predicted prices for CSCO:
# Day 1: 63.99
# Day 2: 64.03
# Day 3: 64.69
# Day 4: 65.75
# Day 5: 65.75
#
# Predicted prices for NXPI:
# Day 1: 236.54
# Day 2: 235.44
# Day 3: 235.22
# Day 4: 235.50
# Day 5: 235.50
#
# Predicted prices for QCOM:
# Day 1: 166.48
# Day 2: 169.77
# Day 3: 170.01
# Day 4: 169.12
# Day 5: 170.02
#
# Predicted prices for DELL:
# Day 1: 117.92
# Day 2: 121.24
# Day 3: 121.43
# Day 4: 121.65
# Day 5: 123.91
#
# Predicted prices for MU:
# Day 1: 99.07
# Day 2: 102.78
# Day 3: 104.00
# Day 4: 103.34
# Day 5: 102.66
#
# Predicted prices for COST:
# Day 1: 1035.13
# Day 2: 1031.22
# Day 3: 1030.94
# Day 4: 1030.83
# Day 5: 1031.04
#
# Predicted prices for WMT:
# Day 1: 94.76
# Day 2: 94.46
# Day 3: 94.91
# Day 4: 95.18
# Day 5: 95.06
#
# Predicted prices for MNST:
# Day 1: 53.10
# Day 2: 54.72
# Day 3: 55.52
# Day 4: 56.25
# Day 5: 55.83
#
# Predicted prices for HSY:
# Day 1: 172.51
# Day 2: 173.71
# Day 3: 171.44
# Day 4: 170.51
# Day 5: 170.23
#
# Predicted prices for PG:
# Day 1: 169.94
# Day 2: 170.57
# Day 3: 169.81
# Day 4: 169.35
# Day 5: 168.93
#
# Predicted prices for CL:
# Day 1: 89.40
# Day 2: 89.85
# Day 3: 91.27
# Day 4: 91.65
# Day 5: 91.09
#
# Predicted prices for KO:
# Day 1: 70.62
# Day 2: 72.14
# Day 3: 73.77
# Day 4: 74.06
# Day 5: 73.42
#
# Predicted prices for PM:
# Day 1: 154.11
# Day 2: 153.43
# Day 3: 153.52
# Day 4: 152.74
# Day 5: 153.32
#
# Predicted prices for MDLZ:
# Day 1: 63.42
# Day 2: 65.91
# Day 3: 66.37
# Day 4: 66.72
# Day 5: 66.96
#
# Predicted prices for KVUE:
# Day 1: 23.29
# Day 2: 24.17
# Day 3: 23.94
# Day 4: 24.01
# Day 5: 22.95
#
# Predicted prices for TGT:
# Day 1: 124.90
# Day 2: 130.80
# Day 3: 133.14
# Day 4: 132.09
# Day 5: 133.36
#
# Predicted prices for KR:
# Day 1: 65.01
# Day 2: 65.91
# Day 3: 66.03
# Day 4: 65.74
# Day 5: 66.01
#
# Predicted prices for GIS:
# Day 1: 60.55
# Day 2: 64.27
# Day 3: 68.70
# Day 4: 67.10
# Day 5: 67.41
#
# Predicted prices for MO:
# Day 1: 55.22
# Day 2: 55.85
# Day 3: 55.76
# Day 4: 55.37
# Day 5: 55.08
#
# Predicted prices for KHC:
# Day 1: 30.68
# Day 2: 29.29
# Day 3: 28.21
# Day 4: 26.04
# Day 5: 27.29
